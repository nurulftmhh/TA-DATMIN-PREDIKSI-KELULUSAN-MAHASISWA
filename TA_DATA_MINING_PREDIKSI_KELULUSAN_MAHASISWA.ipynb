# %% [markdown]
# # Prediksi Kelulusan Mahasiswa
#
# #### Nama : Nurul Fatimah
# #### NPM  : 212103013
# #### Prodi : Sistem Informasi
# #### Semester : 5
# #### Mata Kuliah : Data Mining 1
# #### Dosen : Herdiesel Santoso, S.T., S.Kom., M.Cs
# #### Link Github :

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### CRISP-DM (Cross Industry Standard Process for Data Mining)

# %% [markdown]
# Dalam data mining terdapat 3 (tiga) metodologi yang bisa diterapkan untuk industry
# maupun penulisan ilmiah. Ketiga metodologi tersebut antara lain KDD (Knowledge Discovery
# ftom Data) (Han and Kamber, 2012), SEMMA (Sample, Explore, Modif, Model, and
# Asses)(Makhabel, 2015), dan CRISP-DM (Cross Industry Standard Process for Data
# Mining)(North, 2012). Namun pada buku ini, metodologi data mining lain diharapkan akan
# dijeaskan secara khusus pada buku edisi lain.
# Data mining menjadi salah satu cabang bidang keilmuan baru dan popular dalam dunia
# computer sehingga beberapa perusahaan-perusahaan besar terus mengembangkan dan
# menyempurnakan metodologi dalam data mining, salah satu metodologi yang berhasil
# dirumuskan adalah CRISP-DM. CRISP-DM diperkenalkan pada tahun 1999 oleh empat
# perusahaan besar, yaitu perusahaan pembuat mobil Daimler-Benz, produsen perangkat keras dan
# perangkat lunak NRC Corp, penyedia asuransi OHRA, dan perusahaan pembuat perangkat
# statistik SPSS, Inc. Tahapan dalam metodologi CRIPS-DM,
# yaitu business understanding, data understanding, data preparation, modeling, evaluation, dan
# deployment :
#
# - Business understanding adalah tahapan awal dari metodologi CRISP-DM. Tahapan business
# understanding berisi tentang menentukan tujuan bisnis, menilai situasi saat ini dan menetapkan
# tujuan dilakukan data mining. Tahapan ini sangat penting, namun sering diabaikan ketika
# seseorang terjun ke dunia data mining.
# - Data understanding adalah kegiatan persiapan, mengevaluasi persyaratan data, dan termasuk
# pengumpulan data. Pada tahapan ini, data yang berhasil dikumpulkan kemudian dideklarasikan
# (bagian mana yang atribut, kelas, dan tipe data).
# - Data preparation, setelah data dikumpulkan, data-data tersebut perlu diidentifikasi, dipilih,
# dibersihkan, kemudian dibangun kedalam bentuk/format yang diinginkan. Data preparation
# disebut juga dengan data pre-processing.
# - Modeling, Model adalah aplikai dari algoritma untuk mencari, mengidentifikasi, dan
# menampilkan pola. Pemilihan algoritma berdasarkan tipe data karena dari tipe data kita bisa
# mengetahui apakah data tersebut akan diestimasi, prediksi, klasifikasi, clustering, atau melihat
# hubungan asosiatif.
# - Evaluation digunakan untuk membantu pengukuran evaluasi pada model. Kita bisa mengukur
# model mana yang paling baik digunakan untuk proses data mining. Ada penerapan klasifikasi,
# pengukuran evaluasi yang banyak digunakan adalah akurasi, sensitivity, sprditivity, G-Mean, F-Measure, dan lai sebagainya.
# - Deployment adalah tahapan akhir dalam CRISP-DM. Setelah model dievaluasi dan dipilih
# algoritma dengan hasil pengukuran terbaik, dilanjutkan ke tahapan deployment. Tahapan
# deployment digunakan untuk melakukan otomatisasi model atau pengembangan aplikasi,
# terintegrasi dengan sistem informasi manajemen atau operasi operasional yang ada.

# %% [markdown]
# ### Business Understanding

# %% [markdown]
# Bagas, Nurul dan Netania adalah Mahasiswa S1 Sistem Informasi Unjaya yang
# tertarik dalam bidang penelitian data mining untuk pendidikan (data mining for
# education). Topik penelitian yang diangkat yaitu kelulusan mahasiswa. Ketiga
# peneliti ingin mengidentifikasi apakah mahasiswa lulus tepat waktu atau tidak
# dengan menerapkan metode data mining terbaik untuk pengolahan data. Dataset
# yang digunakan untuk identifikasi kelulusan mahasiswa berasal dari salah satu
# platform penyedia dataset yaitu Kaggle.

# %% [markdown]
# ### Data Understanding

# %% [markdown]
# Dataset Kelulusan Mahasiswa memiliki 2 data yaitu data train sebanyak 379 dan
# data test sebanyak 145. Kedua data tersebut memiliki 15 atribut. Kelima belas
# atribut pada dataset Kelulusan Mahasiswa adalah sebagai berikut :
# 1. Nama : berisi data nama dari mahasiswa
# 2. Jenis Kelamin : berisi data jenis kelamin dari mahasiswa
# 3. Status Mahasiswa : berisi data status mahasiswa, apakah sambil bekerja atau
# tidak
# 4. Umur : berisi data umur dari mahasiswa
# 5. Status Nikah : berisi data status nikah mahasiswa, apakah sudah menikah
# atau belum
# 6. IPS 1 : berisi data indeks prestasi sementara semester 1 dengan interval nilai
# 1-4
# 7. IPS 2 : berisi data indeks prestasi sementara semester 2 dengan interval nilai
# 1-4
# 8. IPS 3 : berisi data indeks prestasi sementara semester 3 dengan interval nilai
# 1-4
# 9. IPS 4 : berisi data indeks prestasi sementara semester 4 dengan interval nilai
# 1-4
# 10. IPS 5 : berisi data indeks prestasi sementara semester 5 dengan interval nilai
# 1-4
# 11. IPS 6 : berisi data indeks prestasi sementara semester 6 dengan interval nilai
# 1-4
# 12. IPS 7 : berisi data indeks prestasi sementara semester 7 dengan interval nilai
# 1-4
# 13. IPS 8 : berisi data indeks prestasi sementara semester 8 dengan interval nilai
# 1-4
# 14. IPK : berisi data indeks prestasi kumulatif dari mahasiswa
# 15. Class, adalah label berisi data tepat jika mahasiswa diidentifikasi lulus
# dengan tepat waktu dan terlambat jika mahasiswa diidentifikasi lulus
# terlambat.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Impor empat library Python yang umum digunakan untuk pemrosesan data dan visualisasi data.
#
# - NumPy adalah library Python untuk komputasi numerik. NumPy menyediakan berbagai fungsi dan tipe data untuk manipulasi data numerik, seperti array multidimensi, matriks, dan vektor.
# - Pandas adalah library Python untuk analisis data. Pandas menyediakan berbagai fungsi dan tipe data untuk manipulasi data tabular, seperti DataFrame dan Series.
# - Matplotlib adalah library Python untuk visualisasi data. Matplotlib menyediakan berbagai fungsi dan tipe data untuk membuat grafik, plot, dan diagram.
# - Seaborn adalah library Python untuk visualisasi data statistik. Seaborn menyediakan berbagai fungsi dan tipe data untuk membuat grafik dan plot yang lebih menarik dan informatif.

# %%
train = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Kelulusan Train.xls')
train.head()
# Out:
#                       NAMA JENIS KELAMIN STATUS MAHASISWA  UMUR  \
# 0           ANIK WIDAYANTI     PEREMPUAN          BEKERJA    28
# 1  DWI HESTYNA PRIHASTANTY     PEREMPUAN        MAHASISWA    32
# 2       MURYA ARIEF BASUKI     PEREMPUAN          BEKERJA    29
# 3            NANIK SUSANTI     PEREMPUAN        MAHASISWA    27
# 4        RIFKA ISTIQFARINA     PEREMPUAN          BEKERJA    29
#
#     STATUS NIKAH  IPS 1  IPS 2  IPS 3  IPS 4  IPS 5  IPS 6  IPS 7  IPS 8  \
# 0  BELUM MENIKAH   2.76   2.80   3.20   3.17   2.98   3.00   3.03    0.0
# 1  BELUM MENIKAH   3.00   3.30   3.14   3.14   2.84   3.13   3.25    0.0
# 2  BELUM MENIKAH   3.50   3.30   3.70   3.29   3.53   3.72   3.73    0.0
# 3  BELUM MENIKAH   3.17   3.41   3.61   3.36   3.48   3.63   3.46    0.0
# 4  BELUM MENIKAH   2.90   2.89   3.30   2.85   2.98   3.00   3.08    0.0
#
#    IPK  STATUS KELULUSAN
# 0  3.07        TERLAMBAT
# 1  3.17        TERLAMBAT
# 2  3.54        TERLAMBAT
# 3  3.41        TERLAMBAT
# ...

# %% [markdown]
# Baca data dari file Excel yang bernama "Kelulusan Train.xls" ke dalam variabel bernama "train". Data tersebut kemudian ditampilkan 5 baris pertamanya menggunakan metode head().

# %%
train.tail()
# Out:
#                             NAMA JENIS KELAMIN STATUS MAHASISWA  UMUR  \
# 374           ARY JULI SETIYANTO   LAKI - LAKI        MAHASISWA    23
# 375          RINA ZAHROTUL UMAMI     PEREMPUAN          BEKERJA    23
# 376  TULISA WAHYUHADI KRISNATAMI     PEREMPUAN        MAHASISWA    23
# 377              NI'MATUL JANNAH     PEREMPUAN        MAHASISWA    23
# 378        DINDU SETYO WICAKSONO   LAKI - LAKI        MAHASISWA    23
#
#       STATUS NIKAH  IPS 1  IPS 2  IPS 3  IPS 4  IPS 5  IPS 6  IPS 7  IPS 8  \
# 374  BELUM MENIKAH   1.98   2.50   2.14   2.77   2.61   2.93   2.82    2.5
# 375  BELUM MENIKAH   2.74   2.75   2.55   3.00   2.98   2.80   3.14    3.0
# 376  BELUM MENIKAH   2.74   2.75   2.55   3.00   2.98   2.80   3.14    3.0
# 377  BELUM MENIKAH   3.02   2.94   3.25   2.87   3.00   2.94   3.09    3.0
# 378  BELUM MENIKAH   3.10   3.06   3.00   3.23   2.79   3.00   2.41    3.0
#
#      IPK  STATUS KELULUSAN
# 374  0.99            TEPAT
# 375  2.97            TEPAT
# ...

# %% [markdown]
# Digunakan untuk menampilkan 5 baris terakhir dari DataFrame bernama train

# %%
train.columns
# Out:
# Index(['NAMA', 'JENIS KELAMIN', 'STATUS MAHASISWA', 'UMUR', 'STATUS NIKAH',
#        'IPS 1', 'IPS 2', 'IPS 3', 'IPS 4', 'IPS 5', 'IPS 6', 'IPS 7', 'IPS 8',
#        'IPK ', 'STATUS KELULUSAN'],
#       dtype='object')

# %% [markdown]
# Menampilkan daftar nama-nama kolom dari DataFrame train.

# %%
train.columns[5]
# Out:
# 'IPS 1'

# %% [markdown]
# Mengakses nama kolom pada indeks ke-5 dari DataFrame train

# %%
train[["NAMA"]]
# Out:
#                             NAMA
# 0                 ANIK WIDAYANTI
# 1        DWI HESTYNA PRIHASTANTY
# 2             MURYA ARIEF BASUKI
# 3                  NANIK SUSANTI
# 4              RIFKA ISTIQFARINA
# ..                           ...
# 374           ARY JULI SETIYANTO
# 375          RINA ZAHROTUL UMAMI
# 376  TULISA WAHYUHADI KRISNATAMI
# 377              NI'MATUL JANNAH
# 378        DINDU SETYO WICAKSONO
#
# [379 rows x 1 columns]

# %% [markdown]
# Menampilkan kolom "NAMA" dari DataFrame train

# %%
train[[train.columns[2], train.columns[7]]]
# Out:
#     STATUS MAHASISWA  IPS 3
# 0            BEKERJA   3.20
# 1          MAHASISWA   3.14
# 2            BEKERJA   3.70
# 3          MAHASISWA   3.61
# 4            BEKERJA   3.30
# ..               ...    ...
# 374        MAHASISWA   2.14
# 375          BEKERJA   2.55
# 376        MAHASISWA   2.55
# 377        MAHASISWA   3.25
# 378        MAHASISWA   3.00
#
# [379 rows x 2 columns]

# %% [markdown]
# Menampilkan dua kolom dari DataFrame train yaitu kolom indeks 2 dan indeks 7.

# %%
train.shape
# Out:
# (379, 15)

# %% [markdown]
# Untuk mendapatkan informasi tentang dimensi (jumlah baris dan kolom) dari DataFrame train.

# %%
train.value_counts('UMUR')
# Out:
# UMUR
# 24    85
# 25    63
# 27    55
# 23    55
# 26    45
# 28    19
# 29    16
# 30    12
# 32    12
# 22     6
# 31     4
# 50     2
# 36     1
# 40     1
# 41     1
# 42     1
# 47     1
# dtype: int64

# %% [markdown]
# Menghitung frekuensi kemunculan setiap nilai dalam kolom "UMUR" pada data frame train.

# %%
test = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Kelulusan Test.xls')
test.head()
# Out:
#                     NAMA JENIS KELAMIN STATUS MAHASISWA  UMUR   STATUS NIKAH  \
# 0                  UNAMA   LAKI - LAKI        MAHASISWA    24  BELUM MENIKAH
# 1  LEYLA TRIYANA PRATIWI     PEREMPUAN        MAHASISWA    26  BELUM MENIKAH
# 2  VERIS SOFIYAN PRAYOGA   LAKI - LAKI        MAHASISWA    29  BELUM MENIKAH
# 3   ADITYA AKBAR NUGRAHA   LAKI - LAKI        MAHASISWA    27  BELUM MENIKAH
# 4       ERNA EKA RIYANTI     PEREMPUAN        MAHASISWA    25  BELUM MENIKAH
#
#    IPS 1  IPS 2  IPS 3  IPS 4  IPS 5  IPS 6  IPS 7  IPS 8  IPK   \
# 0   3.17   2.70   3.23   2.41   3.00   2.47   1.75   0.00  2.75
# 1   3.60   3.50   3.42   2.85   3.31   2.95   2.18   0.00  3.39
# 2   2.67   2.66   2.93   3.14   2.92   2.64   2.88   0.50  2.81
# 3   2.48   2.86   2.09   2.55   2.55   2.43   2.55   2.17  2.82
# 4   3.19   3.08   3.31   2.83   3.36   2.73   3.06   0.00  3.09
#
#   STATUS KELULUSAN
# 0            TEPAT
# 1            TEPAT
# 2            TEPAT
# 3            TEPAT
# ...

# %% [markdown]
# Baca data dari file Excel yang bernama "Kelulusan Test.xls" ke dalam variabel bernama "train". Data tersebut kemudian ditampilkan 5 baris pertamanya menggunakan metode head().

# %%
test.tail()
# Out:
#                             NAMA JENIS KELAMIN STATUS MAHASISWA  UMUR  \
# 140           ARY JULI SETIYANTO   LAKI - LAKI        MAHASISWA    23
# 141          RINA ZAHROTUL UMAMI     PEREMPUAN          BEKERJA    23
# 142  TULISA WAHYUHADI KRISNATAMI     PEREMPUAN        MAHASISWA    23
# 143              NI'MATUL JANNAH     PEREMPUAN        MAHASISWA    23
# 144        DINDU SETYO WICAKSONO   LAKI - LAKI        MAHASISWA    23
#
#       STATUS NIKAH  IPS 1  IPS 2  IPS 3  IPS 4  IPS 5  IPS 6  IPS 7  IPS 8  \
# 140  BELUM MENIKAH   1.98   2.50   2.14   2.77   2.61   2.93   2.82    2.5
# 141  BELUM MENIKAH   2.74   2.75   2.55   3.00   2.98   2.80   3.14    3.0
# 142  BELUM MENIKAH   2.74   2.75   2.55   3.00   2.98   2.80   3.14    3.0
# 143  BELUM MENIKAH   3.02   2.94   3.25   2.87   3.00   2.94   3.09    3.0
# 144  BELUM MENIKAH   3.10   3.06   3.00   3.23   2.79   3.00   2.41    3.0
#
#      IPK  STATUS KELULUSAN
# 140  0.99            TEPAT
# 141  2.97            TEPAT
# ...

# %% [markdown]
# Digunakan untuk menampilkan 5 baris terakhir dari DataFrame bernama test

# %%
test.columns
# Out:
# Index(['NAMA', 'JENIS KELAMIN', 'STATUS MAHASISWA', 'UMUR', 'STATUS NIKAH',
#        'IPS 1', 'IPS 2', 'IPS 3', 'IPS 4', 'IPS 5', 'IPS 6', 'IPS 7', 'IPS 8',
#        'IPK ', 'STATUS KELULUSAN'],
#       dtype='object')

# %% [markdown]
# Menampilkan daftar nama-nama kolom dari DataFrame test.

# %%
test.columns[7]
# Out:
# 'IPS 3'

# %% [markdown]
# Mengakses nama kolom pada indeks ke-7 dari DataFrame test

# %%
test[["STATUS KELULUSAN"]]
# Out:
#     STATUS KELULUSAN
# 0              TEPAT
# 1              TEPAT
# 2              TEPAT
# 3              TEPAT
# 4              TEPAT
# ..               ...
# 140            TEPAT
# 141            TEPAT
# 142            TEPAT
# 143            TEPAT
# 144            TEPAT
#
# [145 rows x 1 columns]

# %% [markdown]
# Menampilkan kolom "STATUS KELULUSAN" dari DataFrame test

# %%
test[[train.columns[0], train.columns[2]]]
# Out:
#                             NAMA STATUS MAHASISWA
# 0                          UNAMA        MAHASISWA
# 1          LEYLA TRIYANA PRATIWI        MAHASISWA
# 2          VERIS SOFIYAN PRAYOGA        MAHASISWA
# 3           ADITYA AKBAR NUGRAHA        MAHASISWA
# 4               ERNA EKA RIYANTI        MAHASISWA
# ..                           ...              ...
# 140           ARY JULI SETIYANTO        MAHASISWA
# 141          RINA ZAHROTUL UMAMI          BEKERJA
# 142  TULISA WAHYUHADI KRISNATAMI        MAHASISWA
# 143              NI'MATUL JANNAH        MAHASISWA
# 144        DINDU SETYO WICAKSONO        MAHASISWA
#
# [145 rows x 2 columns]

# %% [markdown]
# Menampilkan dua kolom dari DataFrame test yaitu kolom indeks 0 dan indeks 2.

# %%
test.shape
# Out:
# (145, 15)

# %% [markdown]
# Untuk mendapatkan informasi tentang dimensi (jumlah baris dan kolom) dari DataFrame test.

# %%
train.value_counts('JENIS KELAMIN')
# Out:
# JENIS KELAMIN
# LAKI - LAKI    234
# PEREMPUAN      145
# dtype: int64

# %% [markdown]
# Menghitung frekuensi kemunculan setiap nilai dalam kolom "JENIS KELAMIN" pada DataFrame test.

# %%
train.describe()
# Out:
#              UMUR       IPS 1       IPS 2       IPS 3       IPS 4       IPS 5  \
# count  379.000000  379.000000  379.000000  379.000000  379.000000  379.000000
# mean    25.955145    2.854116    2.812322    2.900950    2.782137    2.782348
# std      3.397103    0.412658    0.473725    0.589364    0.648495    0.593472
# min     22.000000    0.330000    0.500000    0.160000    0.000000    0.200000
# 25%     24.000000    2.600000    2.550000    2.550000    2.460000    2.480000
# 50%     25.000000    2.860000    2.850000    2.980000    2.860000    2.850000
# 75%     27.000000    3.100000    3.105000    3.325000    3.200000    3.205000
# max     50.000000    3.790000    3.960000    3.960000    3.910000    3.880000
#
#             IPS 6       IPS 7       IPS 8        IPK
# count  379.000000  379.000000  379.000000  376.000000
# mean     2.877256    2.531240    1.248338    2.933085
# std      0.634412    0.757205    1.398434    0.460279
# ...

# %% [markdown]
# Menampilkan statistik deskriptif dari setiap kolom numerik dalam DataFrame train untuk mendapatkan gambaran singkat tentang distribusi data-nya.

# %%
test.describe()
# Out:
#              UMUR       IPS 1       IPS 2       IPS 3       IPS 4       IPS 5  \
# count  145.000000  145.000000  145.000000  145.000000  145.000000  145.000000
# mean    24.475862    2.882345    2.893862    2.857310    2.990828    2.932552
# std      2.395258    0.358099    0.414159    0.540566    0.513567    0.423699
# min     22.000000    1.790000    0.500000    0.160000    0.320000    1.130000
# 25%     23.000000    2.620000    2.660000    2.480000    2.770000    2.700000
# 50%     24.000000    2.900000    2.910000    2.930000    3.000000    2.980000
# 75%     25.000000    3.100000    3.140000    3.270000    3.270000    3.240000
# max     40.000000    3.710000    3.790000    3.960000    3.910000    3.780000
#
#             IPS 6       IPS 7       IPS 8        IPK
# count  145.000000  145.000000  145.000000  145.000000
# mean     2.903034    2.579379    1.879379    2.888828
# std      0.591917    0.746163    1.522290    0.642356
# ...

# %% [markdown]
# Menampilkan statistik deskriptif dari setiap kolom numerik dalam DataFrame test untuk mendapatkan gambaran singkat tentang distribusi data-nya.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_palette('husl')

# %% [markdown]
# Mengimpor modul yang diperlukan untuk membuat grafik visualisasi data dengan Seaborn dan mengatur palet warna yang akan digunakan oleh Seaborn.

# %%
train
# Out:
#                             NAMA JENIS KELAMIN STATUS MAHASISWA  UMUR  \
# 0                 ANIK WIDAYANTI     PEREMPUAN          BEKERJA    28
# 1        DWI HESTYNA PRIHASTANTY     PEREMPUAN        MAHASISWA    32
# 2             MURYA ARIEF BASUKI     PEREMPUAN          BEKERJA    29
# 3                  NANIK SUSANTI     PEREMPUAN        MAHASISWA    27
# 4              RIFKA ISTIQFARINA     PEREMPUAN          BEKERJA    29
# ..                           ...           ...              ...   ...
# 374           ARY JULI SETIYANTO   LAKI - LAKI        MAHASISWA    23
# 375          RINA ZAHROTUL UMAMI     PEREMPUAN          BEKERJA    23
# 376  TULISA WAHYUHADI KRISNATAMI     PEREMPUAN        MAHASISWA    23
# 377              NI'MATUL JANNAH     PEREMPUAN        MAHASISWA    23
# 378        DINDU SETYO WICAKSONO   LAKI - LAKI        MAHASISWA    23
#
#       STATUS NIKAH  IPS 1  IPS 2  IPS 3  IPS 4  IPS 5  IPS 6  IPS 7  IPS 8  \
# ...

# %%
plt.figure(figsize=[18,8])
sns.heatmap(train[[ "UMUR", "IPS 1", "IPS 2", "IPS 3", "IPS 4", "IPS 5", "IPS 6", "IPS 7", "IPS 8"]].corr(method='pearson'), annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Menghasilkan heatmap yang menampilkan korelasi antara kolom-kolom yang dipilih

# %% [markdown]
# ### Data Preparation

# %%
train.isna().sum()
# Out:
# NAMA                0
# JENIS KELAMIN       0
# STATUS MAHASISWA    0
# UMUR                0
# STATUS NIKAH        0
# IPS 1               0
# IPS 2               0
# IPS 3               0
# IPS 4               0
# IPS 5               0
# IPS 6               0
# IPS 7               0
# IPS 8               0
# IPK                 3
# STATUS KELULUSAN    0
# dtype: int64

# %% [markdown]
# Menghitung jumlah nilai yang hilang (missing values) dalam setiap kolom DataFrame train.

# %%
test.isna().sum()
# Out:
# NAMA                0
# JENIS KELAMIN       0
# STATUS MAHASISWA    0
# UMUR                0
# STATUS NIKAH        0
# IPS 1               0
# IPS 2               0
# IPS 3               0
# IPS 4               0
# IPS 5               0
# IPS 6               0
# IPS 7               0
# IPS 8               0
# IPK                 0
# STATUS KELULUSAN    0
# dtype: int64

# %% [markdown]
# Menghitung jumlah nilai yang hilang (missing values) dalam setiap kolom DataFrame test.

# %%
train['JENIS KELAMIN'] = train['JENIS KELAMIN'].apply(lambda x: 1 if x == "LAKI - LAKI" else 0)
train['STATUS MAHASISWA'] = train['STATUS MAHASISWA'].apply(lambda x: 1 if x == "MAHASISWA" else 0)
train['STATUS NIKAH'] = train['STATUS NIKAH'].apply(lambda x: 1 if x == "BELUM MENIKAH" else 0)

# %% [markdown]
# Mengubah data kategorikal menjadi data numerik pada DataFrame train
# - Data kategorikal "LAKI - LAKI" pada kolom JENIS KELAMIN menjadi nilai numerik 1, sedangkan data kategorikal lainnya diubah menjadi nilai numerik 0.
# - Data kategorikal "MAHASISWA" pada kolom STATUS MAHASISWA menjadi nilai numerik 1, sedangkan data kategorikal lainnya diubah menjadi nilai numerik 0.
# - Data kategorikal "BELUM MENIKAH" pada kolom STATUS NIKAH menjadi nilai numerik 1, sedangkan data kategorikal lainnya diubah menjadi nilai numerik 0.

# %%
test['JENIS KELAMIN'] = test['JENIS KELAMIN'].apply(lambda x: 1 if x == "LAKI - LAKI" else 0)
test['STATUS MAHASISWA'] = test['STATUS MAHASISWA'].apply(lambda x: 1 if x == "MAHASISWA" else 0)
test['STATUS NIKAH'] = test['STATUS NIKAH'].apply(lambda x: 1 if x == "BELUM MENIKAH" else 0)

# %% [markdown]
# Mengubah data kategorikal menjadi data numerik pada DataFrame test
# - Data kategorikal "LAKI - LAKI" pada kolom JENIS KELAMIN menjadi nilai numerik 1, sedangkan data kategorikal lainnya diubah menjadi nilai numerik 0.
# - Data kategorikal "MAHASISWA" pada kolom STATUS MAHASISWA menjadi nilai numerik 1, sedangkan data kategorikal lainnya diubah menjadi nilai numerik 0.
# - Data kategorikal "BELUM MENIKAH" pada kolom STATUS NIKAH menjadi nilai numerik 1, sedangkan data kategorikal lainnya diubah menjadi nilai numerik 0.

# %%
train
# Out:
#                             NAMA  JENIS KELAMIN  STATUS MAHASISWA  UMUR  \
# 0                 ANIK WIDAYANTI              0                 0    28
# 1        DWI HESTYNA PRIHASTANTY              0                 1    32
# 2             MURYA ARIEF BASUKI              0                 0    29
# 3                  NANIK SUSANTI              0                 1    27
# 4              RIFKA ISTIQFARINA              0                 0    29
# ..                           ...            ...               ...   ...
# 374           ARY JULI SETIYANTO              1                 1    23
# 375          RINA ZAHROTUL UMAMI              0                 0    23
# 376  TULISA WAHYUHADI KRISNATAMI              0                 1    23
# 377              NI'MATUL JANNAH              0                 1    23
# 378        DINDU SETYO WICAKSONO              1                 1    23
#
#      STATUS NIKAH  IPS 1  IPS 2  IPS 3  IPS 4  IPS 5  IPS 6  IPS 7  IPS 8  \
# ...

# %%
test
# Out:
#                             NAMA  JENIS KELAMIN  STATUS MAHASISWA  UMUR  \
# 0                          UNAMA              1                 1    24
# 1          LEYLA TRIYANA PRATIWI              0                 1    26
# 2          VERIS SOFIYAN PRAYOGA              1                 1    29
# 3           ADITYA AKBAR NUGRAHA              1                 1    27
# 4               ERNA EKA RIYANTI              0                 1    25
# ..                           ...            ...               ...   ...
# 140           ARY JULI SETIYANTO              1                 1    23
# 141          RINA ZAHROTUL UMAMI              0                 0    23
# 142  TULISA WAHYUHADI KRISNATAMI              0                 1    23
# 143              NI'MATUL JANNAH              0                 1    23
# 144        DINDU SETYO WICAKSONO              1                 1    23
#
#      STATUS NIKAH  IPS 1  IPS 2  IPS 3  IPS 4  IPS 5  IPS 6  IPS 7  IPS 8  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NAMA              379 non-null    object
#  1   JENIS KELAMIN     379 non-null    int64
#  2   STATUS MAHASISWA  379 non-null    int64
#  3   UMUR              379 non-null    int64
#  4   STATUS NIKAH      379 non-null    int64
#  5   IPS 1             379 non-null    float64
#  6   IPS 2             379 non-null    float64
#  7   IPS 3             379 non-null    float64
#  8   IPS 4             379 non-null    float64
#  9   IPS 5             379 non-null    float64
#  10  IPS 6             379 non-null    float64
#  11  IPS 7             379 non-null    float64
#  12  IPS 8             379 non-null    float64
#  13  IPK               376 non-null    float64
#  14  STATUS KELULUSAN  379 non-null    object
# dtypes: float64(9), int64(4), object(2)
# memory usage: 44.5+ KB

# %% [markdown]
# Menampilkan ringkasan dari struktur dan informasi dari DataFrame train

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NAMA              145 non-null    object
#  1   JENIS KELAMIN     145 non-null    int64
#  2   STATUS MAHASISWA  145 non-null    int64
#  3   UMUR              145 non-null    int64
#  4   STATUS NIKAH      145 non-null    int64
#  5   IPS 1             145 non-null    float64
#  6   IPS 2             145 non-null    float64
#  7   IPS 3             145 non-null    float64
#  8   IPS 4             145 non-null    float64
#  9   IPS 5             145 non-null    float64
#  10  IPS 6             145 non-null    float64
#  11  IPS 7             145 non-null    float64
#  12  IPS 8             145 non-null    float64
#  13  IPK               145 non-null    float64
#  14  STATUS KELULUSAN  145 non-null    object
# dtypes: float64(9), int64(4), object(2)
# memory usage: 17.1+ KB

# %% [markdown]
# Menampilkan ringkasan dari struktur dan informasi dari DataFrame test

# %%
x_train = train[['JENIS KELAMIN', 'STATUS MAHASISWA', 'STATUS NIKAH','UMUR', 'IPS 1', 'IPS 2', 'IPS 3', 'IPS 4', 'IPS 5', 'IPS 6', 'IPS 7', 'IPS 8']]
y_train = train['STATUS KELULUSAN']

# %% [markdown]
# Memisahkan kolom-kolom yang akan digunakan sebagai fitur (x) dari kolom yang akan digunakan sebagai target (y) dari data train.

# %%
x_train
# Out:
#      JENIS KELAMIN  STATUS MAHASISWA  STATUS NIKAH  UMUR  IPS 1  IPS 2  IPS 3  \
# 0                0                 0             1    28   2.76   2.80   3.20
# 1                0                 1             1    32   3.00   3.30   3.14
# 2                0                 0             1    29   3.50   3.30   3.70
# 3                0                 1             1    27   3.17   3.41   3.61
# 4                0                 0             1    29   2.90   2.89   3.30
# ..             ...               ...           ...   ...    ...    ...    ...
# 374              1                 1             1    23   1.98   2.50   2.14
# 375              0                 0             1    23   2.74   2.75   2.55
# 376              0                 1             1    23   2.74   2.75   2.55
# 377              0                 1             1    23   3.02   2.94   3.25
# 378              1                 1             1    23   3.10   3.06   3.00
#
# ...

# %%
y_train
# Out:
# 0      TERLAMBAT
# 1      TERLAMBAT
# 2      TERLAMBAT
# 3      TERLAMBAT
# 4      TERLAMBAT
#          ...
# 374        TEPAT
# 375        TEPAT
# 376        TEPAT
# 377        TEPAT
# 378        TEPAT
# Name: STATUS KELULUSAN, Length: 379, dtype: object

# %%
x_test = test[['JENIS KELAMIN', 'STATUS MAHASISWA', 'STATUS NIKAH', 'UMUR', 'IPS 1', 'IPS 2', 'IPS 3', 'IPS 4', 'IPS 5', 'IPS 6', 'IPS 7', 'IPS 8']]
y_test = test['STATUS KELULUSAN']

# %% [markdown]
# Memisahkan kolom-kolom yang akan digunakan sebagai fitur (x) dari kolom yang akan digunakan sebagai target (y) dari data test.

# %%
x_test
# Out:
#      JENIS KELAMIN  STATUS MAHASISWA  STATUS NIKAH  UMUR  IPS 1  IPS 2  IPS 3  \
# 0                1                 1             1    24   3.17   2.70   3.23
# 1                0                 1             1    26   3.60   3.50   3.42
# 2                1                 1             1    29   2.67   2.66   2.93
# 3                1                 1             1    27   2.48   2.86   2.09
# 4                0                 1             1    25   3.19   3.08   3.31
# ..             ...               ...           ...   ...    ...    ...    ...
# 140              1                 1             1    23   1.98   2.50   2.14
# 141              0                 0             1    23   2.74   2.75   2.55
# 142              0                 1             1    23   2.74   2.75   2.55
# 143              0                 1             1    23   3.02   2.94   3.25
# 144              1                 1             1    23   3.10   3.06   3.00
#
# ...

# %%
y_test
# Out:
# 0      TEPAT
# 1      TEPAT
# 2      TEPAT
# 3      TEPAT
# 4      TEPAT
#        ...
# 140    TEPAT
# 141    TEPAT
# 142    TEPAT
# 143    TEPAT
# 144    TEPAT
# Name: STATUS KELULUSAN, Length: 145, dtype: object

# %% [markdown]
# ### Modelling

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

k_range = list(range(1,26))
scores = []
for k in k_range:
  knn = KNeighborsClassifier(n_neighbors = k, p = 1)
  knn.fit(x_train, y_train)
  y_pred1 = knn.predict(x_test)
  scores.append(accuracy_score(y_test, y_pred1))

plt.plot(k_range, scores)
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors Manhattan')
plt.show()

scores_list = [(i + 1, score) for i, score in enumerate(scores)]

print('Nilai Akurasi', scores_list)
print('Nilai Tertinggi :', max(scores))
# Out:
# Nilai Akurasi [(1, 1.0), (2, 0.993103448275862), (3, 0.9586206896551724), (4, 0.9724137931034482), (5, 0.9448275862068966), (6, 0.9448275862068966), (7, 0.9310344827586207), (8, 0.9379310344827586), (9, 0.9379310344827586), (10, 0.9448275862068966), (11, 0.9241379310344827), (12, 0.9310344827586207), (13, 0.9103448275862069), (14, 0.9310344827586207), (15, 0.9103448275862069), (16, 0.9241379310344827), (17, 0.903448275862069), (18, 0.9103448275862069), (19, 0.903448275862069), (20, 0.9103448275862069), (21, 0.9103448275862069), (22, 0.9172413793103448), (23, 0.9172413793103448), (24, 0.9172413793103448), (25, 0.9172413793103448)]
# Nilai Tertinggi : 1.0

# %% [markdown]
# Melakukan pencarian nilai k terbaik (hyperparameter tuning) pada model K-Nearest Neighbors (KNN) dengan jarak Manhattan dan untuk mengevaluasi performa model tersebut berdasarkan akurasi.

# %%
k_range = list(range(1,26))
scores = []
for k in k_range:
  knn = KNeighborsClassifier(n_neighbors = k, p = 2)
  knn.fit(x_train, y_train)
  y_pred2= knn.predict(x_test)
  scores.append(accuracy_score(y_test, y_pred2))

plt.plot(k_range, scores)
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors Euclidean')
plt.show()

scores_list = [(i + 1, score) for i, score in enumerate(scores)]

print('Nilai Akurasi', scores_list)
print('Nilai Tertinggi :', max(scores))
# Out:
# Nilai Akurasi [(1, 1.0), (2, 0.993103448275862), (3, 0.9586206896551724), (4, 0.9586206896551724), (5, 0.9655172413793104), (6, 0.9724137931034482), (7, 0.9379310344827586), (8, 0.9517241379310345), (9, 0.9310344827586207), (10, 0.9241379310344827), (11, 0.9172413793103448), (12, 0.9172413793103448), (13, 0.9172413793103448), (14, 0.9172413793103448), (15, 0.903448275862069), (16, 0.9172413793103448), (17, 0.903448275862069), (18, 0.9103448275862069), (19, 0.896551724137931), (20, 0.9172413793103448), (21, 0.903448275862069), (22, 0.9103448275862069), (23, 0.8896551724137931), (24, 0.896551724137931), (25, 0.8896551724137931)]
# Nilai Tertinggi : 1.0

# %% [markdown]
# Melakukan pencarian nilai k terbaik (hyperparameter tuning) pada model K-Nearest Neighbors (KNN) dengan jarak Euclidean dan untuk mengevaluasi performa model tersebut berdasarkan akurasi.

# %%
k_range = list(range(1,26))
scores = []
for k in k_range:
  knn = KNeighborsClassifier(n_neighbors = k, p = 3, metric='minkowski')
  knn.fit(x_train, y_train)
  y_pred3 = knn.predict(x_test)
  scores.append(accuracy_score(y_test, y_pred3))

plt.plot(k_range, scores)
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors Minkowski')
plt.show()

scores_list = [(i + 1, score) for i, score in enumerate(scores)]

print('Nilai Akurasi', scores_list)
print('Nilai Tertinggi :', max(scores))
# Out:
# Nilai Akurasi [(1, 1.0), (2, 0.993103448275862), (3, 0.9517241379310345), (4, 0.9724137931034482), (5, 0.9379310344827586), (6, 0.9517241379310345), (7, 0.9379310344827586), (8, 0.9379310344827586), (9, 0.9172413793103448), (10, 0.9103448275862069), (11, 0.9172413793103448), (12, 0.9172413793103448), (13, 0.896551724137931), (14, 0.903448275862069), (15, 0.896551724137931), (16, 0.9172413793103448), (17, 0.903448275862069), (18, 0.903448275862069), (19, 0.903448275862069), (20, 0.9103448275862069), (21, 0.903448275862069), (22, 0.903448275862069), (23, 0.8896551724137931), (24, 0.903448275862069), (25, 0.8827586206896552)]
# Nilai Tertinggi : 1.0

# %% [markdown]
# Melakukan pencarian nilai k terbaik (hyperparameter tuning) pada model K-Nearest Neighbors (KNN) dengan jarak Minkowski dan untuk mengevaluasi performa model tersebut berdasarkan akurasi.

# %%
knn = KNeighborsClassifier(n_neighbors = 1, p = 1)
knn.fit(x_train,y_train)
y_pred1 = knn.predict(x_test)

print("Accuracy Score of KNN Manhattan:", accuracy_score(y_test,y_pred1))
# Out:
# Accuracy Score of KNN Manhattan: 1.0

# %% [markdown]
# Melatih dan mengevaluasi performa model K-Nearest Neighbors (KNN) dengan jarak Manhattan, menggunakan nilai k=1.

# %%
knn = KNeighborsClassifier(n_neighbors = 1, p = 2)
knn.fit(x_train, y_train)
y_pred1 = knn.predict(x_test)

print("Accuracy Score of KNN Euclidean:", accuracy_score(y_test,y_pred2))
# Out:
# Accuracy Score of KNN Euclidean: 0.8896551724137931

# %% [markdown]
# Melatih dan mengevaluasi performa model K-Nearest Neighbors (KNN) dengan jarak Euclidean, menggunakan nilai k=1.

# %%
knn = KNeighborsClassifier(n_neighbors = 1, p = 3, metric='minkowski')
knn.fit(x_train,y_train)
y_pred1 = knn.predict(x_test)

print("Accuracy Score of KNN Minkowski :", accuracy_score(y_test,y_pred3))
# Out:
# Accuracy Score of KNN Minkowski : 0.8827586206896552

# %% [markdown]
# Melatih dan mengevaluasi performa model K-Nearest Neighbors (KNN) dengan jarak Minkowski, menggunakan nilai k=1.

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(x_train, y_train)
y_pred_nb = nb.predict(x_test)

print("Accuracy Score of NB :", accuracy_score(y_test,y_pred_nb))
# Out:
# Accuracy Score of NB : 0.9379310344827586

# %% [markdown]
# Melatih dan mengevaluasi performa model Naive Bayes (NB)

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
y_pred_svc = svc.predict(x_test)

print("Accuracy Score of SVC :", accuracy_score(y_test,y_pred_svc))
# Out:
# Accuracy Score of SVC : 0.896551724137931

# %% [markdown]
# Melatih dan mengevaluasi performa model Support Vector Machine (SVM)

# %% [markdown]
# ### EVALUATION

# %%
from sklearn.metrics import classification_report

knn = KNeighborsClassifier(n_neighbors = 1, p=1)
knn.fit(x_train,y_train)
y_pred = knn.predict(x_test)

print("Confusion Matrix Untuk Manhattan")
matrix = classification_report(y_test, y_pred)
print(matrix)
# Out:
# Confusion Matrix Untuk Manhattan
#               precision    recall  f1-score   support
#
#        TEPAT       1.00      1.00      1.00       143
#    TERLAMBAT       1.00      1.00      1.00         2
#
#     accuracy                           1.00       145
#    macro avg       1.00      1.00      1.00       145
# weighted avg       1.00      1.00      1.00       145

# %% [markdown]
# Menghasilkan laporan klasifikasi (classification report) yang detail untuk model K-Nearest Neighbors (KNN) dengan jarak Manhattan, yang memberikan insight lebih mendalam tentang performa model di luar nilai akurasi.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy score : {} ".format(accuracy_score(y_test, y_pred)))
print("Precision score : {} ".format(precision_score(y_test, y_pred, average='macro')))
print("Recall score : {} ".format(recall_score(y_test, y_pred, average='macro')))
print("F1 score : {} ".format(f1_score(y_test, y_pred, average='macro')))
# Out:
# Accuracy score : 1.0
# Precision score : 1.0
# Recall score : 1.0
# F1 score : 1.0

# %% [markdown]
# Menghitung dan mencetak empat metrik evaluasi yang berbeda untuk menilai performa dari model KNN dengan jarak manhattan

# %%
from sklearn.metrics import roc_auc_score, roc_curve

knn.fit(x_train, y_train)

y_pred_proba = knn.predict_proba(x_test)[:, 1]
y_test_aktual= np.where(y_test == 'TEPAT', 1, 0)
y_test_predic= np.where(y_pred == 'TEPAT', 1, 0)
auc_score = roc_auc_score(y_test, y_test_predic, multi_class='ovo')

def plot_roc_curve(true_y, y_prob):
    fpr, tpr, thresholds = roc_curve(true_y, y_prob)
    plt.plot(fpr, tpr,  lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

plot_roc_curve(y_test_aktual, y_test_predic)

# %% [markdown]
# Menghitung dan memvisualisasikan ROC AUC Score dan membuat kurva ROC untuk model KNN, yang membantu menilai kemampuan model dalam membedakan antara kelas positif dan negatif.
